# %%
import pyam
import pandas as pd

data = [
    ["HR_Model", "Baseline", "Company", "IT Salary", "USD", 2023, 60000],
    ["HR_Model", "Baseline", "Company", "IT Salary", "USD", 2024, 62000],
    ["HR_Model", "Growth",   "Company", "IT Salary", "USD", 2023, 60000],
    ["HR_Model", "Growth",   "Company", "IT Salary", "USD", 2024, 68000],

    ["HR_Model", "Baseline", "Company", "HR Salary", "USD", 2023, 50000],
    ["HR_Model", "Baseline", "Company", "HR Salary", "USD", 2024, 51000],
    ["HR_Model", "Growth",   "Company", "HR Salary", "USD", 2023, 50000],
    ["HR_Model", "Growth",   "Company", "HR Salary", "USD", 2024, 56000],
]

df = pd.DataFrame(
    data,
    columns=["model", "scenario", "region", "variable", "unit", "year", "value"]
)

iam_df = pyam.IamDataFrame(df)
iam_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pyam
#       2 import pandas as pd
#       4 data = [
#       5     ["HR_Model", "Baseline", "Company", "IT Salary", "USD", 2023, 60000],
#       6     ["HR_Model", "Baseline", "Company", "IT Salary", "USD", 2024, 62000],
#    (...)     13     ["HR_Model", "Growth",   "Company", "HR Salary", "USD", 2024, 56000],
#      14 ]
#
# File c:\Users\deltagare\Desktop\python workspace\.venv\Lib\site-packages\pyam\__init__.py:12
#       9 except ModuleNotFoundError:
#      10     from importlib_metadata import version, PackageNotFoundError
# ---> 12 from pyam.core import *
#      13 from pyam.utils import *
#      14 from pyam.statistics import *
#
# File c:\Users\deltagare\Desktop\python workspace\.venv\Lib\site-packages\pyam\core.py:66
#      58 from pyam._compare import _compare
# ...
